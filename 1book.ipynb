# %%
#import all packages 
import pandas as pd
import warnings
import statsmodels.api as sm
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import statsmodels.api as sm
import seaborn as sns
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings('ignore')

data = pd.read_csv('kc_house_data.csv')

# %%
data.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
# 5    101930     1.0         NO  NONE  ...   11 Excellent       3890
# 6      6819     2.0         NO  NONE  ...      7 Average       1715
# 7      9711     1.0         NO   NaN  ...      7 Average       1060
# 8      7470     1.0         NO  NONE  ...      7 Average       1050
# 9      6560     2.0         NO  NONE  ...      7 Average       1890
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0            0.0     1955           0.0    98178  47.5112 -122.257
# 1          400.0     1951        1991.0    98125  47.7210 -122.319
# 2            0.0     1933           NaN    98028  47.7379 -122.233
# 3          910.0     1965           0.0    98136  47.5208 -122.393
# 4            0.0     1987           0.0    98074  47.6168 -122.045
# 5         1530.0     2001           0.0    98053  47.6561 -122.005
# 6              ?     1995           0.0    98003  47.3097 -122.327
# 7            0.0     1963           0.0    98198  47.4095 -122.315
# 8          730.0     1960           0.0    98146  47.5123 -122.337
# 9            0.0     2003           0.0    98038  47.3684 -122.031
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
# 5           4760      101930
# 6           2238        6819
# 7           1650        9711
# 8           1780        8113
# 9           2390        7570
#
# [10 rows x 21 columns]

# %%
# drop columns that have no desire to our stakeholder 
clean_null = data.drop(columns=['id','date','condition','sqft_living15','sqft_lot15','floors','view', 'waterfront', 'yr_renovated'], axis=1)
clean_null
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot          grade  \
# 0      221900.0         3       1.00         1180      5650      7 Average
# 1      538000.0         3       2.25         2570      7242      7 Average
# 2      180000.0         2       1.00          770     10000  6 Low Average
# 3      604000.0         4       3.00         1960      5000      7 Average
# 4      510000.0         3       2.00         1680      8080         8 Good
# ...         ...       ...        ...          ...       ...            ...
# 21592  360000.0         3       2.50         1530      1131         8 Good
# 21593  400000.0         4       2.50         2310      5813         8 Good
# 21594  402101.0         2       0.75         1020      1350      7 Average
# 21595  400000.0         3       2.50         1600      2388         8 Good
# 21596  325000.0         2       0.75         1020      1076      7 Average
#
#        sqft_above sqft_basement  yr_built  zipcode      lat     long
# 0            1180           0.0      1955    98178  47.5112 -122.257
# 1            2170         400.0      1951    98125  47.7210 -122.319
# 2             770           0.0      1933    98028  47.7379 -122.233
# 3            1050         910.0      1965    98136  47.5208 -122.393
# 4            1680           0.0      1987    98074  47.6168 -122.045
# ...           ...           ...       ...      ...      ...      ...
# 21592        1530           0.0      2009    98103  47.6993 -122.346
# 21593        2310           0.0      2014    98146  47.5107 -122.362
# 21594        1020           0.0      2009    98144  47.5944 -122.299
# 21595        1600           0.0      2004    98027  47.5345 -122.069
# 21596        1020           0.0      2008    98144  47.5941 -122.299
#
# [21597 rows x 12 columns]

# %%
clean_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21597 non-null  float64
#  1   bedrooms       21597 non-null  int64
#  2   bathrooms      21597 non-null  float64
#  3   sqft_living    21597 non-null  int64
#  4   sqft_lot       21597 non-null  int64
#  5   grade          21597 non-null  object
#  6   sqft_above     21597 non-null  int64
#  7   sqft_basement  21597 non-null  object
#  8   yr_built       21597 non-null  int64
#  9   zipcode        21597 non-null  int64
#  10  lat            21597 non-null  float64
#  11  long           21597 non-null  float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 2.0+ MB

# %%
clean_null['sqft_basement']df.astype({'col1': 'int32'}).dtypes

# %%
clean_null['true_sqft'] = clean_null['sqft_living']  - clean_null['sqft_basement']
clean_null
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-209-269fd068eab0> in <module>
# ----> 1 clean_null['true_sqft'] = clean_null['sqft_living']  - clean_null['sqft_basement']
#       2 clean_null
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      90         if mask.any():
#      91             with np.errstate(all="ignore"):
# ---> 92                 result[mask] = op(xrav[mask], yrav[mask])
#      93
#      94     else:
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
test = [i[0:2].strip() for i in clean_null['grade']]

# %%
clean_null['grade_ordinal'] = [int(i[0:2].strip()) for i in clean_null['grade']]

# %%
# creating a new feature of price per sqft
clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_above']
clean_null
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_l
# yr_built        0.053953  0.155670   0.507173     0.318152  0.052946
# zipcode        -0.053402 -0.154092  -0.204786    -0.199802 -0.129586
# lat             0.306692 -0.009951   0.024280     0.052155 -0.085514
# long            0.022036  0.132054   0.224903     0.241214  0.230227
# price_per_sqft  0.578937 -0.075068  -0.001625     0.039930 -0.048217
# grade_ordinal   0.667951  0.356563   0.665838     0.762779  0.114731
#
#                 sqft_above  yr_built   zipcode       lat      long  \
# price             0.605368  0.053953 -0.053402  0.306692  0.022036
# bedrooms          0.479386  0.155670 -0.154092 -0.009951  0.132054
# bathrooms         0.686668  0.507173 -0.204786  0.024280  0.224903
# sqft_living       0.876448  0.318152 -0.199802  0.052155  0.241214
# sqft_lot          0.184139  0.052946 -0.129586 -0.085514  0.230227
# sqft_above        1.000000  0.424037 -0.261570 -0.001199  0.344842
# yr_built          0.424037  1.000000 -0.347210 -0.148370  0.409993
# zipcode          -0.261570 -0.347210  1.000000  0.266742 -0.564259
# lat              -0.001199 -0.148370  0.266742  1.000000 -0.135371
# long              0.344842  0.409993 -0.564259 -0.135371  1.000000
# price_per_sqft   -0.188362 -0.343851  0.208965  0.458387 -0.298222
# grade_ordinal     0.756073  0.447865 -0.185771  0.113575  0.200341
#
#                 price_per_sqft  grade_ordinal
# price                 0.578937       0.667951
# bedrooms             -0.075068       0.356563
# bathrooms            -0.001625       0.665838
# sqft_living           0.039930       0.762779
# sqft_lot             -0.048217       0.114731
# sqft_above           -0.188362       0.756073
# yr_built             -0.343851       0.447865
# zipcode               0.208965      -0.185771
# lat                   0.458387       0.113575
# long                 -0.298222       0.200341
# price_per_sqft        1.000000       0.121996
# grade_ordinal         0.121996       1.000000

# %%
y = clean_null['price']
x = clean_null['sqft_living']
X_c = sm.add_constant(x)


simple_model = sm.OLS(y, X_c)


simple_model_results = simple_model.fit()
print(simple_model_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.097e+04
# Date:                Tue, 25 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:51:21   Log-Likelihood:            -3.0006e+05
# No. Observations:               21597   AIC:                         6.001e+05
# Df Residuals:                   21595   BIC:                         6.001e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.399e+04   4410.023     -9.975      0.000   -5.26e+04   -3.53e+04
# sqft_living   280.8630      1.939    144.819      0.000     277.062     284.664
# ==============================================================================
# Omnibus:                    14801.942   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           542662.604
# Skew:                           2.820   Prob(JB):                         0.00
# Kurtosis:                      26.901   Cond. No.                     5.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
clean_null.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'zipcode', 'lat', 'long',
#        'price_per_sqft', 'grade_ordinal'],
#       dtype='object')

# %%
clean_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           21597 non-null  float64
#  1   bedrooms        21597 non-null  int64
#  2   bathrooms       21597 non-null  float64
#  3   sqft_living     21597 non-null  int64
#  4   sqft_lot        21597 non-null  int64
#  5   grade           21597 non-null  object
#  6   sqft_above      21597 non-null  int64
#  7   sqft_basement   21597 non-null  object
#  8   yr_built        21597 non-null  int64
#  9   zipcode         21597 non-null  int64
#  10  lat             21597 non-null  float64
#  11  long            21597 non-null  float64
#  12  price_per_sqft  21597 non-null  float64
#  13  grade_ordinal   21597 non-null  int64
# dtypes: float64(5), int64(7), object(2)
# memory usage: 2.3+ MB

# %%
#reviewing coef and p value significants 
y = clean_null['price']
X = clean_null.drop(['price','grade','sqft_basement'], axis=1)





y = y.dropna()
X = X.dropna()

# len(y), len(X)
ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
ols_kch.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0
# price_per_sqft    0.148202 -0.703087  0.779127 -0.653193 -0.721245
# grade_ordinal     0.719060  0.205433  0.295443  0.191162 -0.295208
#
#                 price_per_sqft  grade_ordinal
# price                 0.711715       0.461908
# bedrooms              0.259340       0.116385
# bathrooms             0.426857       0.532907
# sqft_living           0.402000       0.589130
# sqft_lot             -0.209855      -0.107742
# sqft_above            0.148202       0.719060
# yr_built             -0.703087       0.205433
# zipcode               0.779127       0.295443
# lat                  -0.653193       0.191162
# long                 -0.721245      -0.295208
# price_per_sqft        1.000000       0.096258
# grade_ordinal         0.096258       1.000000

# %%
clean_null['zipcode'].unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039], dtype=int64)

# %%
clean_null.shape
# Out:
# (21597, 14)

# %%
clean_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           21597 non-null  float64
#  1   bedrooms        21597 non-null  int64
#  2   bathrooms       21597 non-null  float64
#  3   sqft_living     21597 non-null  int64
#  4   sqft_lot        21597 non-null  int64
#  5   grade           21597 non-null  object
#  6   sqft_above      21597 non-null  int64
#  7   sqft_basement   21597 non-null  object
#  8   yr_built        21597 non-null  int64
#  9   zipcode         21597 non-null  int64
#  10  lat             21597 non-null  float64
#  11  long            21597 non-null  float64
#  12  price_per_sqft  21597 non-null  float64
#  13  grade_ordinal   21597 non-null  int64
# dtypes: float64(5), int64(7), object(2)
# memory usage: 2.3+ MB

# %%
clean_null.head(5)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot          grade  \
# 0  221900.0         3       1.00         1180      5650      7 Average
# 1  538000.0         3       2.25         2570      7242      7 Average
# 2  180000.0         2       1.00          770     10000  6 Low Average
# 3  604000.0         4       3.00         1960      5000      7 Average
# 4  510000.0         3       2.00         1680      8080         8 Good
#
#    sqft_above sqft_basement  yr_built  zipcode      lat     long  \
# 0        1180           0.0      1955    98178  47.5112 -122.257
# 1        2170         400.0      1951    98125  47.7210 -122.319
# 2         770           0.0      1933    98028  47.7379 -122.233
# 3        1050         910.0      1965    98136  47.5208 -122.393
# 4        1680           0.0      1987    98074  47.6168 -122.045
#
#    price_per_sqft  grade_ordinal
# 0      188.050847              7
# 1      247.926267              7
# 2      233.766234              6
# 3      575.238095              7
# 4      303.571429              8

# %%
#Linearity
X = clean_null.drop(['price','price_per_sqft'], axis=1).select_dtypes(float,int)
ss = StandardScaler().fit(X)

X_scaled = ss.transform(X)

# %%
X_c = sm.add_constant(X_scaled)
y = clean_null['price']

# %%
model = sm.OLS(endog=y, exog=X_c).fit()

# %%
model_preds = model.predict(X_c)
resids = y - model_preds

fig, ax = plt.subplots()

ax.scatter(model_preds, resids)
ax.set_xlabel('predicted home prices')
ax.set_ylabel('residual')
plt.suptitle('Residuals Vs. Predictions');

# %%
fig, ax = plt.subplots(ncols=1, figsize=(8, 6))


ax.scatter(X['bathrooms'], y)
ax.set_title('Home Price Price vs. Size');

# %%
fig, ax = plt.subplots()

ax.scatter(y, resids);

# %%
dw = sm.stats.stattools.durbin_watson

# %%
dw(resids)
# Out:
# 1.9687771452935094

# %%
model.summary().tables[2]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
resids.hist(bins=50);

# %%
sm.qqplot(resids, line='r');

# %%
# %history
# Out:
# #import all packages
# import pandas as pd
# import pandas as pd
# import warnings
# import statsmodels.api as sm
#
# warnings.filterwarnings('ignore')
#
# data = pd.read_csv('kc_house_data.csv')
# clean_null = data.drop(columns=['view', 'waterfront', 'yr_renovated'], axis=1)
# clean_null
# clean_null['condition'].unique()
# clean_null['grade'].unique()
# data.head(10)
# # drop columns that have no desire to our stakeholder
# clean_null = data.drop(columns=['view', 'waterfront', 'yr_renovated'], axis=1)
# clean_null
# clean_null.info()
# clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_living']
# clean_null
# # eda stats
# clean_null.describe()
# clean_null['']
# # eda correlations
# clean_null.corr()
#
# y = clean_null['price']
# x = clean_null['sqft_living']
# X_c = sm.add_constant(x)
#
#
# simple_model = sm.OLS(y, X_c)
#
#
# simple_model_results = simple_model.fit()
# print(simple_model_results.summary())
# clean_null.columns
# clean_null.info()
# y = clean_null['price']
# X = clean_null.drop(['id','date','sqft_living15','sqft_above','sqft_lot15','yr_built','price', 'date', 'sqft_basement', 'grade',
#                      'condition'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# w = print("{:f}".format(1.13e+13))  # f represents float
# clean_null['bedrooms']
# clean_null['sqft_lot']
# clean_null['sqft_lot'].min()
# clean_null['sqft_lot'].describe()
# #find the largest lots for development
# filter_lot_size = clean_null.loc[clean_null['sqft_lot'] > 10000 ]
# #find the largest lots for development
# filter_lot_size = clean_null.loc[clean_null['sqft_lot'] > 10000 ]
# #find the largest lots for development
# filter_lot_size = clean_null.loc[clean_null['sqft_lot'] > 10000 ]
# filter_lot_size
# #find the largest lots for development
# filter_lot_size = clean_null.loc[clean_null['sqft_lot'] > 500000 ]
# filter_lot_size
# filter_lot_size.shape
# zip_lot_size = clean_null(clean_null.loc['zipcode' = '98004','98052','98101','98103','98104', '98109',
#                                                      '98119','98121','98134','98164')]
# zip_lot_size = clean_null(clean_null.loc['zipcode' == '98004','98052','98101','98103','98104', '98109',
#                                                      '98119','98121','98134','98164')]
# clean_null['zipcode'].unique()
# zip_lot_size = clean_null(clean_null.loc['zipcode' == '98004','98052','98101','98103','98104', '98109',
#                                                      '98119','98121','98134','98164'])
# zip_lot_size = clean_null(clean_null.loc['zipcode' == '98004','98052','98101','98103','98104',
#                                                      '98109','98119','98121','98134','98164'])
# zip_lot_size = clean_null(clean_null.loc['zipcode' == '98063'])
# zip_lot_size = clean_null(clean_null.loc['zipcode' == '98033'])
# zip_lot_size = clean_null(clean_null.loc['zipcode' == '98052'])
# zip_lot_size = clean_null(clean_null.loc['zipcode' = '98052'])
# zip_lot_size = clean_null(clean_null.loc[['zipcode'] = '98052'])
# zip_lot_size = clean_null(clean_null.loc[['zipcode'] == '98052'])
# zip_lot_size = clean_null(clean_null.loc[['zipcode'] == '98053'])
# zip_lot_size = clean_null(clean_null.loc['zipcode' == '98053'])
# zip_lot_size = clean_null.loc(clean_null['zipcode' == '98053'])
# zip_lot_size = clean_null.loc[clean_null['zipcode' == '98053')
# zip_lot_size = clean_null.loc[clean_null['zipcode' == '98053']
# zip_lot_size = clean_null.loc[clean_null['zipcode'] == '98053'
# zip_lot_size = clean_null.loc[clean_null['zipcode'] = '98053'
# zip_lot_size = clean_null.loc[clean_null['zipcode'] == '98053' ]
# zip_lot_size = clean_null.loc[clean_null['zipcode'] == '98053']
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'] == '98052']
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'] == 98052]
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'] == '98052','98102','98103','98105',
#                                                      '98109','98119','98121','98134','98164']
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'] == 98052]
# zip_lot_size
# clean_null['zipcoe'].isin(['98052','98102','98103','98105','98109','98119','98121','98134','98164'])
# clean_null['zipcode'].isin(['98052','98102','98103','98105','98109','98119','98121','98134','98164'])
# clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])
# zip_lot_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]) == 9805]
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])]
# zip_lot_size
# zip_lot_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])] & clean_null['sqft_lot'] >=200000
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 200000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 20000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 200000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 100000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 50000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 5000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 20000)]
#
# zip_lot_size
# zip_lot_size.shape
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 22000)]
#
# zip_lot_size
# zip_lot_size.shape
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 30000)]
#
# zip_lot_size
# zip_lot_size.shape
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# zip_lot_size.shape
# # drop columns that have no desire to our stakeholder
# clean_null = data.drop(columns=['id','date','view', 'waterfront', 'yr_renovated'], axis=1)
# clean_null
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 100000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 50000)]
#
# zip_lot_size
# zip_lot_size.shape
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 22000)]
#
# zip_lot_size
# zip_lot_size.shape
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 30000)]
#
# zip_lot_size
# zip_lot_size.shape
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# zip_lot_size.shape
# # drop columns that have no desire to our stakeholder
# clean_null = data.drop(columns=['id','date','condition','sqft_living15','sqft_lot15','floors ','view', 'waterfront', 'yr_renovated'], axis=1)
# clean_null
# # drop columns that have no desire to our stakeholder
# clean_null = data.drop(columns=['id','date','condition','sqft_living15','sqft_lot15','floors','view', 'waterfront', 'yr_renovated'], axis=1)
# clean_null
# clean_null.info()
# clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_living']
# clean_null
# # eda stats
# clean_null.describe()
# # eda correlations
# clean_null.corr()
#
# y = clean_null['price']
# x = clean_null['sqft_living']
# X_c = sm.add_constant(x)
#
#
# simple_model = sm.OLS(y, X_c)
#
#
# simple_model_results = simple_model.fit()
# print(simple_model_results.summary())
# clean_null.columns
# clean_null.info()
# y = clean_null['price']
# X = clean_null.drop(['id','date','sqft_living15','sqft_above','sqft_lot15','yr_built','price', 'date', 'sqft_basement', 'grade',
#                      'condition'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# w = print("{:f}".format(1.13e+13))  # f represents float
# clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# zip_lot_size.shape
# clean_null['zipcode'].unique()
# #find the largest lots for development
# filter_lot_size = clean_null.loc[clean_null['sqft_lot'] > 500000 ]
# filter_lot_size
# filter_lot_size.shape
# y = clean_null['price']
# X = clean_null.drop([,'sqft_above','yr_built','price', 'date', 'sqft_basement', 'grade',
#                      'condition'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# y = clean_null['price']
# X = clean_null.drop(['sqft_above','yr_built','price', 'date', 'sqft_basement', 'grade',
#                      'condition'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# y = clean_null['price']
# X = clean_null.drop(['sqft_above','yr_built','price', 'date', 'sqft_basement', 'grade',
#                      'condition'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# w = print("{:f}".format(1.13e+13))  # f represents float
# clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])
# y = clean_null['price']
# X = clean_null.drop(['sqft_above','yr_built','price', 'date', 'sqft_basement', 'grade',
#                      'condition'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# y = clean_null['price']
# X = clean_null.drop(['price'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# zip_lot_size.shape
# y = clean_null['price']
# X = clean_null.drop(['price'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# #identifying the lots we recommend the stakeholder purchase and build new multifamily homes.
#
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# y = clean_null['price']
# X = clean_null.drop(['price','grade'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# y = clean_null['price']
# X = clean_null.drop(['price','grade','sqft_basement'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# clean_null['condition'].unique()
# clean_null['grade'].unique()
# data.head(10)
# # drop columns that have no desire to our stakeholder
# clean_null = data.drop(columns=['id','date','condition','sqft_living15','sqft_lot15','floors','view', 'waterfront', 'yr_renovated'], axis=1)
# clean_null
# data.head(10)
# # drop columns that have no desire to our stakeholder
# clean_null = data.drop(columns=['id','date','condition','sqft_living15','sqft_lot15','floors','view', 'waterfront', 'yr_renovated'], axis=1)
# clean_null
# clean_null.info()
# # creating a new feature of price per sqft
# clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_living']
# clean_null
# # eda stats
# clean_null.describe()
# # eda correlations
# clean_null.corr()
#
# y = clean_null['price']
# x = clean_null['sqft_living']
# X_c = sm.add_constant(x)
#
#
# simple_model = sm.OLS(y, X_c)
#
#
# simple_model_results = simple_model.fit()
# print(simple_model_results.summary())
# clean_null.columns
# clean_null.info()
# #reviewing coef and p value significants
# y = clean_null['price']
# X = clean_null.drop(['price','grade','sqft_basement'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# #identifying the lots we recommend the stakeholder purchase and build new multifamily homes.
#
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# zip_lot_size.shape
# clean_null['zipcode'].unique()
# filter_lot_size.shape
# # we have 17 lots for the stakeholder investment projects
# zip_lot_size.shape
# X = zip_lot_size.select_dtypes(float)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# #import all packages
# import pandas as pd
# import warnings
# import statsmodels.api as sm
# import numpy as np
# from matplotlib import pyplot as plt
# from scipy import stats
# import statsmodels.api as sm
# import seaborn as sns
# from sklearn.preprocessing import StandardScaler
# warnings.filterwarnings('ignore')
#
# data = pd.read_csv('kc_house_data.csv')
# X = zip_lot_size.select_dtypes(float)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = zip_lot_size['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted diamond prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['x'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['sqft_above'], y)
# ax2.set_title('Home Price Price vs. Size');
# X = clean_null.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = zip_lot_size['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# X = zip_lot_size.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = zip_lot_size['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['sqft_above'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# X = clean_null_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X = clean_null.dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X = clean_null.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = zip_lot_size['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# X = zip_lot_size.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = zip_lot_size['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# dw = sm.stats.stattools.durbin_watson
# dw(resids)
# model.summary().tables[2]
# resids.hist(bins=50);
# resids.hist(bins=20);
# resids.hist(bins=10);
# resids.hist(bins=5);
# resids.hist(bins=15);
# sm.qqplot(resids, line='r');
# model.summary().tables[2]
# y.hist();
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# zip_lot_size.describe()
# zip_home_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]
#
# zip_home_size
# zip_home_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]]
#
# zip_home_size
# zip_home_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])]
#
# zip_home_size
# zip_home_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])]
#
# zip_home_size
# # homes in the tech company zones zip_home_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])]
#
# zip_home_size
# # homes in the tech company zones
# zip_home_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])]
#
# zip_home_size
# #identifying the lots we recommend the stakeholder purchase and build new multifamily homes.
#
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# # we have 17 lots for the stakeholder investment projects
# zip_lot_size.shape
# zip_home_size.descibe()
# zip_home_size.describe()
# #Linearity
# X = zip_lot_size.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# zip_lot_size.corr()
# #Linearity
# X = clean_null.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = zip_lot_size['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# clean_null.shape
# #Linearity
# X = zip_lot_size.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = zip_lot_size['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# X_c = sm.add_constant(X_scaled)
# y = clean_null['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# model = sm.OLS(endog=y, exog=X_c).fit()
# clean_null.head(5)
# clean_null.info()
# # creating a new feature of price per sqft
# clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_above']
# clean_null
# # creating a new feature of price per sqft
# clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_living']
# clean_null
# # creating a new feature of price per sqft
# clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_above']
# clean_null
# true_sqft['true_sqft'] = clean_null['sqft_living']  - clean_null['sqft_basement']
# clean_null
# clen_null['true_sqft'] = clean_null['sqft_living']  - clean_null['sqft_basement']
# clean_null
# clean_null['true_sqft'] = clean_null['sqft_living']  - clean_null['sqft_basement']
# clean_null
# #Linearity
# X = clean_null.select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = clean_null['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# #Linearity
# X = clean_null.drop('price', axis=1)select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# #Linearity
# X = clean_null.drop('price', axis=1), select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# #Linearity
# X = clean_null.drop('price', axis=1).select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = clean_null['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# dw = sm.stats.stattools.durbin_watson
# dw(resids)
# model.summary().tables[2]
# resids.hist(bins=15);
# sm.qqplot(resids, line='r');
# model.summary().tables[2]
# y.hist();
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# #Linearity
# X = clean_null.drop(['price','price_per_sqft'], axis=1).select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = clean_null['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.scatter(X['price_per_sqft'], y)
# ax1.set_title('home Price vs. price_per_sqft')
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# dw = sm.stats.stattools.durbin_watson
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
# ax1.set_title('home Price vs 'sqft_living')
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
#
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, (ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
#
# ax2.scatter(X['bathrooms'], y)
# ax2.set_title('Home Price Price vs. Size');
# fig, (ax1) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
#
# ax1.scatter(X['bathrooms'], y)
# ax1.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))
#
#
# ax.scatter(X['bathrooms'], y)
# ax.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots(ncols=1, figsize=(8, 6))
#
#
# ax.scatter(X['bathrooms'], y)
# ax.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# dw = sm.stats.stattools.durbin_watson
# dw(resids)
# model.summary().tables[2]
# resids.hist(bins=25);
# resids.hist(bins=45);
# clean_null.describe()
# fig, ax = plt.subplots()
#
# ax.scatter(price);
# fig, ax = plt.subplots()
#
# ax.scatter('price');
# fig, ax = plt.subplots()
#
# ax.scatter(clean_null='price', );
# fig, ax = plt.subplots()
#
# ax.scatter(clean_null='price');
# fig, ax = plt.subplots()
#
# ax.scatter(clean_null=['price']);
# fig, ax = plt.subplots()
#
# ax.scatter(y=['price'], x=clean_null.index;
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null.index;
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null.index);
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null['sqft_living'];
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null['sqft_living']);
# y_log = np.log(y)
# y_log.hist();
# # 'x1' is the carat variable
# sm.graphics.plot_regress_exog(model, 'x1', fig=plt.figure(figsize=(12, 8)));
# clean_null.describe()
# #identifying the lots we recommend the stakeholder purchase and build new multifamily homes.
#
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 1000)]
#
# zip_lot_size
# #identifying the lots we recommend the stakeholder purchase and build new multifamily homes.
#
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 40000)]
#
# zip_lot_size
# #identifying the lots we recommend the stakeholder purchase and build new multifamily homes.
#
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 20000)]
#
# zip_lot_size
# # we have 17 lots for the stakeholder investment projects
# zip_lot_size.shape
# resids.hist(bins=30);
# resids.hist(bins=50);
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null['bedroom']);
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null['bedrooms']);
# clean_null.describe()
# %history
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null['bathroom']);
# fig, ax = plt.subplots()
#
# ax.scatter(y=clean_null['price'], x=clean_null['bathrooms']);
# test = [i[0:2].strip() for i in df_simple['grade']]
# test = [i[0:2].strip() for i in clean_null['grade']]
# test = [i[0:2].strip() for i in clean_null['grade']]
# test
# test = [i[0:2].strip() for i in clean_null['grade']]
# grade_or['grade_ordinal'] = [int(i[0:2].strip()) for i in grade_or['grade']]
# test = [i[0:2].strip() for i in clean_null['grade']]
# grade_or['grade_ordinal'] = [int(i[0:2].strip()) for i in grade_or['grade']]
# grade_or['grade_ordinal'] = [int(i[0:2].strip()) for i in test['grade']]
# kchousing['grade_ordinal'] = [int(i[0:2].strip()) for i in clean_null['grade']]
# clean_null['grade_ordinal'] = [int(i[0:2].strip()) for i in clean_null['grade']]
# # creating a new feature of price per sqft
# clean_null['price_per_sqft'] = clean_null['price']  / clean_null['sqft_above']
# clean_null
# # eda stats
# clean_null.describe()
# # eda correlations
# clean_null.corr()
#
# y = clean_null['price']
# x = clean_null['sqft_living']
# X_c = sm.add_constant(x)
#
#
# simple_model = sm.OLS(y, X_c)
#
#
# simple_model_results = simple_model.fit()
# print(simple_model_results.summary())
# clean_null.columns
# clean_null.info()
# #reviewing coef and p value significants
# y = clean_null['price']
# X = clean_null.drop(['price','grade','sqft_basement'], axis=1)
#
#
#
#
#
# y = y.dropna()
# X = X.dropna()
#
# # len(y), len(X)
# ols_kch = sm.OLS(y, sm.add_constant(X)).fit()
# ols_kch.summary()
# # homes in the tech company zones
# zip_home_size = clean_null.loc[clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164])]
#
# zip_home_size
# zip_home_size.describe()
# #identifying the lots we recommend the stakeholder purchase and build new multifamily homes.
#
# zip_lot_size = clean_null.loc[(clean_null['zipcode'].isin([98052,98102,98103,98105,98109,98119,98121,98134,98164]))
#                               & (clean_null['sqft_lot'] >= 20000)]
#
# zip_lot_size
# # we have 17 lots for the stakeholder investment projects
# zip_lot_size.shape
# zip_lot_size.describe()
# zip_lot_size.corr()
# clean_null['zipcode'].unique()
# clean_null.shape
# clean_null.info()
# clean_null.head(5)
# #Linearity
# X = clean_null.drop(['price','price_per_sqft'], axis=1).select_dtypes(float,int)
# ss = StandardScaler().fit(X)
#
# X_scaled = ss.transform(X)
# X_c = sm.add_constant(X_scaled)
# y = clean_null['price']
# model = sm.OLS(endog=y, exog=X_c).fit()
# model_preds = model.predict(X_c)
# resids = y - model_preds
#
# fig, ax = plt.subplots()
#
# ax.scatter(model_preds, resids)
# ax.set_xlabel('predicted home prices')
# ax.set_ylabel('residual')
# plt.suptitle('Residuals Vs. Predictions');
# fig, ax = plt.subplots(ncols=1, figsize=(8, 6))
#
#
# ax.scatter(X['bathrooms'], y)
# ax.set_title('Home Price Price vs. Size');
# fig, ax = plt.subplots()
#
# ax.scatter(y, resids);
# dw = sm.stats.stattools.durbin_watson
# dw(resids)
# model.summary().tables[2]
# resids.hist(bins=50);
# sm.qqplot(resids, line='r');
# %history

# %%
fig, ax = plt.subplots()

ax.scatter(y=clean_null['price'], x=clean_null['bathrooms']);

# %%
clean_null['grade]

# %%
clean_null.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   5.402966e+05      3.373200      2.115826   2080.321850  1.509941e+04
# std    3.673681e+05      0.926299      0.768984    918.106125  4.141264e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068500e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#          sqft_above      yr_built       zipcode           lat          long  \
# count  21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean    1788.596842   1970.999676  98077.951845     47.560093   -122.213982
# std      827.759761     29.375234     53.513072      0.138552      0.140724
# min      370.000000   1900.000000  98001.000000     47.155900   -122.519000
# 25%     1190.000000   1951.000000  98033.000000     47.471100   -122.328000
# 50%     1560.000000   1975.000000  98065.000000     47.571800   -122.231000
# 75%     2210.000000   1997.000000  98118.000000     47.678000   -122.125000
# max     9410.000000   2015.000000  98199.000000     47.777600   -121.315000
#
#        price_per_sqft  grade_ordinal
# count    21597.000000   21597.000000
# mean       314.932069       7.657915
# std        147.454847       1.173200
# min         87.588235       3.000000
# 25%        206.489676       7.000000
# 50%        280.373832       7.000000
# 75%        391.441441       8.000000
# max       1516.746411      13.000000

# %%
model.summary().tables[2]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
y.hist();

# %%
fig, ax = plt.subplots()

ax.scatter(y, resids);

# %%
y_log = np.log(y)
y_log.hist();

# %%
# 'x1' is 
sm.graphics.plot_regress_exog(model, 'x1', fig=plt.figure(figsize=(12, 8)));

# %%
zip_home_size

# %%
o_drop = ['id', 'date', 'view', 'sqft_above', 
           'sqft_basement', 'yr_renovated', 
           'zipcode', 'lat', 'long', 
           'sqft_living15', 'sqft_lot15']

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')
